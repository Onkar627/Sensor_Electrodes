# %% [markdown]
# <a href="https://colab.research.google.com/github/Onkar627/Sensor_Electrodes/blob/main/images_chitosan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('plt35.png')
plt.axis('off')
imS = cv2.resize(img1, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp1.png")

# %%
img2 = cv2.imread('plt36.png')
plt.axis('off')
imS = cv2.resize(img2, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp2.png")

# %%
img3 = cv2.imread('plt37.png')
plt.axis('off')
imS = cv2.resize(img3, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp3.png")

# %%
img4 = cv2.imread('plt38.png')
plt.axis('off')
imS = cv2.resize(img4, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp4.png")

# %%
img5 = cv2.imread('plt39.png')
plt.axis('off')
imS = cv2.resize(img5, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp5.png")

# %%
img6 = cv2.imread('plt40.png')
plt.axis('off')
imS = cv2.resize(img6, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp6.png")

# %%
img7 = cv2.imread('plt41.png')
plt.axis('off')
imS = cv2.resize(img7, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp7.png")

# %%
img8 = cv2.imread('plt42.png')
plt.axis('off')
imS = cv2.resize(img8, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp8.png")

# %%
img9 = cv2.imread('plt43.png')
plt.axis('off')
imS = cv2.resize(img9, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp9.png")

# %%
img10 = cv2.imread('plt44.png')
plt.axis('off')
imS = cv2.resize(img10, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp10.png")

# %%
img11 = cv2.imread('plt45.png')
plt.axis('off')
imS = cv2.resize(img11, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp11.png")

# %%
img12 = cv2.imread('plt46.png')
plt.axis('off')
imS = cv2.resize(img12, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp12.png")

# %%
img13 = cv2.imread('plt47.png')
plt.axis('off')
imS = cv2.resize(img13, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp13.png")

# %%
img14 = cv2.imread('plt48.png')
plt.axis('off')
imS = cv2.resize(img14, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp14.png")
