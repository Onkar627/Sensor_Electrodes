# %% [markdown]
# <a href="https://colab.research.google.com/github/Onkar627/Sensor_Electrodes/blob/main/bare_images1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('plt1.png')
plt.axis('off')
imS = cv2.resize(img, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp1.png")

# %%
img2 = cv2.imread('plt2.png')
plt.axis('off')
imS = cv2.resize(img2, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp2.png")

# %%
img3 = cv2.imread('plt3.png')
plt.axis('off')
plt.savefig("test.png")
imS = cv2.resize(img3, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp3.png")

# %%
img4 = cv2.imread('plt4.png')
plt.axis('off')
imS = cv2.resize(img4, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp4.png")

# %%
img5 = cv2.imread('plt5.png')
plt.axis('off')
imS = cv2.resize(img4, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp5.png")

# %%
img7 = cv2.imread('plt7.png')
plt.axis('off')
imS = cv2.resize(img7, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp7.png")

# %%
img8 = cv2.imread('plt8.png')
plt.axis('off')
imS = cv2.resize(img8, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp8.png")

# %%
img9 = cv2.imread('plt9.png')
plt.axis('off')
imS = cv2.resize(img9, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp9.png")

# %%
img10 = cv2.imread('plt10.png')
plt.axis('off')
imS = cv2.resize(img10, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp10.png")

# %%
img12 = cv2.imread('plt12.png')
plt.axis('off')
imS = cv2.resize(img12, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp12.png")

# %%
img13 = cv2.imread('plt13.png')
plt.axis('off')
imS = cv2.resize(img13, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp13.png")

# %%
img14 = cv2.imread('plt14.png')
plt.axis('off')
imS = cv2.resize(img14, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp14.png")

# %%
img15 = cv2.imread('plt15.png')
plt.axis('off')
imS = cv2.resize(img15, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp15.png")

# %%
img16 = cv2.imread('plt16.png')
plt.axis('off')
imS = cv2.resize(img16, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp16.png")
