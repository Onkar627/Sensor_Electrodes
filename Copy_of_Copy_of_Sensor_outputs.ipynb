# %% [markdown]
# <a href="https://colab.research.google.com/github/Onkar627/Sensor_Electrodes/blob/main/Copy_of_Copy_of_Sensor_outputs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
df = pd.read_excel('/content/bare pvp go-chitosan chitosan 0.001 V-s.txt.xlsx')
df2 = pd.read_excel('/content/bare pvp go-chitosan chitosan 0.002 V-s.txt.xlsx')
df3 = pd.read_excel('/content/bare pvp go-chitosan chitosan 0.004 V-s.txt.xlsx')
df4 = pd.read_excel('/content/bare pvp go-chitosan 0.006V-s.txt.xlsx')
df5 = pd.read_excel('/content/bare pvp go-chitosan 0.008V-s.txt.xlsx')
df6 = pd.read_excel('/content/bare pvp go-chitosan 0.01V-s.txt.xlsx')
df7 = pd.read_excel('/content/bare pvp go-chitosan 0.02V-s.txt.xlsx')
df8 = pd.read_excel('/content/bare pvp go-chitosan 0.04V-s.txt.xlsx')
df9 = pd.read_excel('/content/bare pvp go-chitosan 0.06V-s.txt.xlsx')
df10 = pd.read_excel('/content/bare pvp go-chitosan 0.08V-s.txt.xlsx')
df11 = pd.read_excel('/content/bare pvp go-chitosan 0.1V-s.txt.xlsx')
df12 = pd.read_excel('/content/bare pvp go-chitosan 0.2V-s.txt.xlsx')
df13 = pd.read_excel('/content/bare pvp go-chitosan 0.4V-s.txt.xlsx')
df14 = pd.read_excel('/content/bare pvp go-chitosan 0.6V-s.txt.xlsx')
df15 = pd.read_excel('/content/bare pvp go-chitosan 0.8V-s.txt.xlsx')
df16 = pd.read_excel('/content/bare pvp go-chitosan 1V-s.txt.xlsx')

# %%
result = pd.concat([df, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16], axis=1, join='inner')
result
# Out:
#       Unnamed: 0  Voltage(V)  Bare Electrode Current (A)  \
# 0              0      -0.200               -2.075000e-05
# 1              1      -0.199               -1.982000e-05
# 2              2      -0.198               -1.902000e-05
# 3              3      -0.197               -1.831000e-05
# 4              4      -0.196               -1.768000e-05
# ...          ...         ...                         ...
# 7995        7995      -0.195               -7.362000e-07
# 7996        7996      -0.196               -7.355000e-07
# 7997        7997      -0.197               -7.349000e-07
# 7998        7998      -0.198               -7.345000e-07
# 7999        7999      -0.199               -7.339000e-07
#
#       PVP Electrode Current (A)  Chitosan Electrode Current(A)  \
# 0                     -0.000021                      -0.000016
# 1                     -0.000020                      -0.000016
# 2                     -0.000019                      -0.000015
# ...

# %%
result_bare = result[['Voltage(V)','Bare Electrode Current (A)']]
result_bare
# Out:
#       Voltage(V)  Voltage(V)  Voltage(V)  Voltage(V)  Voltage(V)  Voltage(V)  \
# 0         -0.200      -0.200      -0.200      -0.200      -0.200      -0.200
# 1         -0.199      -0.199      -0.199      -0.199      -0.199      -0.199
# 2         -0.198      -0.198      -0.198      -0.198      -0.198      -0.198
# 3         -0.197      -0.197      -0.197      -0.197      -0.197      -0.197
# 4         -0.196      -0.196      -0.196      -0.196      -0.196      -0.196
# ...          ...         ...         ...         ...         ...         ...
# 7995      -0.195      -0.195      -0.195      -0.195      -0.195      -0.195
# 7996      -0.196      -0.196      -0.196      -0.196      -0.196      -0.196
# 7997      -0.197      -0.197      -0.197      -0.197      -0.197      -0.197
# 7998      -0.198      -0.198      -0.198      -0.198      -0.198      -0.198
# 7999      -0.199      -0.199      -0.199      -0.199      -0.199      -0.199
#
# ...

# %%
plt.plot(result_bare['Voltage(V)'],result_bare['Bare Electrode Current (A)'])

# %%
result_PVP = result[['Voltage(V)','PVP Electrode Current (A)']]
result_PVP
plt.plot(result_PVP['Voltage(V)'],result_PVP['PVP Electrode Current (A)'])

# %%
result_Chitosan = result[['Voltage(V)','Chitosan Electrode Current(A)']]
result_Chitosan
plt.plot(result_Chitosan['Voltage(V)'],result_Chitosan['Chitosan Electrode Current(A)'])

# %%
result_ChitosanGO = result[['Voltage(V)','Chitosan GO Electrode Current(A)']]
result_ChitosanGO
plt.plot(result_ChitosanGO['Voltage(V)'],result_ChitosanGO['Chitosan GO Electrode Current(A)'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(result_bare)
# Out:
# StandardScaler()

# %%
scaled_df = scaler.transform(result_bare)
scaled_df
# Out:
# array([[-1.7320481 , -1.7320481 , -1.7320481 , ..., -0.42343758,
#         -0.42553716, -0.43249118],
#        [-1.72771798, -1.72771798, -1.72771798, ..., -0.41268983,
#         -0.41415899, -0.42091226],
#        [-1.72338786, -1.72338786, -1.72338786, ..., -0.40793011,
#         -0.40861213, -0.41471889],
#        ...,
#        [-1.71905774, -1.71905774, -1.71905774, ..., -1.97833087,
#         -2.01606329, -2.03617093],
#        [-1.72338786, -1.72338786, -1.72338786, ..., -1.97986626,
#         -2.01890783, -2.0388637 ],
#        [-1.72771798, -1.72771798, -1.72771798, ..., -1.97986626,
#         -2.0203301 , -2.04155647]])

# %%
pd.DataFrame(scaled_df).describe()
# Out:
#                  0             1             2             3             4   \
# count  8.000000e+03  8.000000e+03  8.000000e+03  8.000000e+03  8.000000e+03
# mean  -7.294165e-17 -7.294165e-17 -7.294165e-17 -7.294165e-17 -7.294165e-17
# std    1.000063e+00  1.000063e+00  1.000063e+00  1.000063e+00  1.000063e+00
# min   -1.732048e+00 -1.732048e+00 -1.732048e+00 -1.732048e+00 -1.732048e+00
# 25%   -8.660241e-01 -8.660241e-01 -8.660241e-01 -8.660241e-01 -8.660241e-01
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    8.660241e-01  8.660241e-01  8.660241e-01  8.660241e-01  8.660241e-01
# max    1.732048e+00  1.732048e+00  1.732048e+00  1.732048e+00  1.732048e+00
#
#                  5             6             7             8             9   \
# count  8.000000e+03  8.000000e+03  8.000000e+03  8.000000e+03  8.000000e+03
# mean  -7.294165e-17 -7.294165e-17 -7.294165e-17 -7.294165e-17 -7.294165e-17
# ...

# %%
pca = PCA(n_components=4)
pca.fit(scaled_df)
x_pca = pca.transform(scaled_df)
x_pca.shape
# Out:
# (8000, 4)

# %%
bare_1 = df[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df['Voltage(V)'],df['Bare Electrode Current (A)'])

# %%
bare_2 = df2[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df2['Voltage(V)'],df2['Bare Electrode Current (A)'])

# %%
bare_3 = df3[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df3['Voltage(V)'],df3['Bare Electrode Current (A)'])

# %%
bare_4 = df4[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df4['Voltage(V)'],df4['Bare Electrode Current (A)'])

# %%
bare_5 = df5[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df5['Voltage(V)'],df5['Bare Electrode Current (A)'])

# %%
bare_6 = df6[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df6['Voltage(V)'],df6['Bare Electrode Current (A)'])

# %%
bare_7 = df7[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df7['Voltage(V)'],df7['Bare Electrode Current (A)'])

# %%
bare_8 = df8[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df8['Voltage(V)'],df8['Bare Electrode Current (A)'])

# %%
bare_9= df9[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df9['Voltage(V)'],df9['Bare Electrode Current (A)'])

# %%
bare_10 = df10[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df10['Voltage(V)'],df10['Bare Electrode Current (A)'])

# %%
bare_11 = df11[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df11['Voltage(V)'],df11['Bare Electrode Current (A)'])

# %%
bare_12 = df12[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df12['Voltage(V)'],df12['Bare Electrode Current (A)'])

# %%
bare_13 = df13[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df13['Voltage(V)'],df13['Bare Electrode Current (A)'])

# %%
bare_14 = df14[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df14['Voltage(V)'],df14['Bare Electrode Current (A)'])

# %%
bare_15 = df15[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df15['Voltage(V)'],df15['Bare Electrode Current (A)'])

# %%
bare_16 = df16[['Voltage(V)','Bare Electrode Current (A)']]
plt.plot(df16['Voltage(V)'],df16['Bare Electrode Current (A)'])

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvas(fig)
ax = fig.gca()

ax.text(0.0,0.0,"Test", fontsize=45)
ax.axis('off')

canvas.print_figure("output.png")
image = plt.imread("output.png")

# %%
import numpy as np
import scipy
import numpy.fft as fft
from scipy import fft as sp_fft
from scipy import signal
import librosa
from librosa import stft
import matplotlib
from matplotlib import colors

def stft(x, Nwin, Nfft=None):
    """
    Short-time Fourier transform: convert a 1D vector to a 2D array

    The short-time Fourier transform (STFT) breaks a long vector into disjoint
    chunks (no overlap) and runs an FFT (Fast Fourier Transform) on each chunk.

    The resulting 2D array can 

    Parameters
    ----------
    x : array_like
        Input signal (expected to be real)
    Nwin : int
        Length of each window (chunk of the signal). Should be ≪ `len(x)`.
    Nfft : int, optional
        Zero-pad each chunk to this length before FFT. Should be ≥ `Nwin`,
        (usually with small prime factors, for fastest FFT). Default: `Nwin`.

    Returns
    -------
    out : complex ndarray
        `len(x) // Nwin` by `Nfft` complex array representing the STFT of `x`.

    See also
    --------
    istft : inverse function (convert a STFT array back to a data vector)
    stftbins : time and frequency bins corresponding to `out`
    """
    Nfft = Nfft or Nwin
    Nwindows = x.size // Nwin
    # reshape into array `Nwin` wide, and as tall as possible. This is
    # optimized for C-order (row-major) layouts.
    arr = np.reshape(x[:Nwindows * Nwin], (-1, Nwin))
    stft = fft.rfft(arr, Nfft)
    return stft


def stftbins(x, Nwin, Nfft=None, d=1.0):
    """
    Time and frequency bins corresponding to short-time Fourier transform.

    Call this with the same arguments as `stft`, plus one extra argument: `d`
    sample spacing, to get the time and frequency axes that the output of
    `stft` correspond to.

    Parameters
    ----------
    x : array_like
        same as `stft`
    Nwin : int
        same as `stft`
    Nfft : int, optional
        same as `stft`
    d : float, optional
        Sample spacing of `x` (or 1 / sample frequency), units of seconds.
        Default: 1.0.

    Returns
    -------
    t : ndarray
        Array of length `len(x) // Nwin`, in units of seconds, corresponding to
        the first dimension (height) of the output of `stft`.
    f : ndarray
        Array of length `Nfft`, in units of Hertz, corresponding to the second
        dimension (width) of the output of `stft`.
    """
    Nfft = Nfft or Nwin
    Nwindows = x.size // Nwin
    t = np.arange(Nwindows) * (Nwin * d)
    f = fft.rfftfreq(Nfft, d)
    return t, f

# %%
Sg1 = scipy.signal.stft(bare_1['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)

# %%
f, Pxx_den = scipy.signal.welch(bare_1['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_1['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt1.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg2 = scipy.signal.stft(bare_2['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_2['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_2['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt2.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg3 = scipy.signal.stft(bare_3['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_3['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_3['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt3.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg4 = scipy.signal.stft(bare_4['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_4['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_4['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt4.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg5 = scipy.signal.stft(bare_5['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_5['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_5['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt5.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg6 = scipy.signal.stft(bare_6['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_6['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_6['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt6.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg7 = scipy.signal.stft(bare_7['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_7['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_7['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt7.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg8 = scipy.signal.stft(bare_8['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_8['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_8['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt8.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg9 = scipy.signal.stft(bare_9['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_9['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_9['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt9.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg10 = scipy.signal.stft(bare_10['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_10['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_10['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt10.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg11 = scipy.signal.stft(bare_11['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_11['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_11['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt11.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg12 = scipy.signal.stft(bare_12['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_12['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_12['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.savefig('plt12.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg13 = scipy.signal.stft(bare_13['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_13['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_13['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt13.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg14 = scipy.signal.stft(bare_14['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_14['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_14['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt14.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg15 = scipy.signal.stft(bare_15['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_15['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_15['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt15.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg16 = scipy.signal.stft(bare_16['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(bare_16['Bare Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(bare_16['Bare Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt16.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
pvp_1 = df[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df['Voltage(V)'],df['PVP Electrode Current (A)'])

# %%
pvp_2 = df2[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df2['Voltage(V)'],df2['PVP Electrode Current (A)'])

# %%
pvp_3 = df3[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df3['Voltage(V)'],df3['PVP Electrode Current (A)'])

# %%
pvp_3 = df3[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df3['Voltage(V)'],df3['PVP Electrode Current (A)'])

# %%
pvp_4 = df4[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df4['Voltage(V)'],df4['PVP Electrode Current (A)'])

# %%
pvp_5 = df5[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df5['Voltage(V)'],df5['PVP Electrode Current (A)'])

# %%
pvp_6 = df6[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df6['Voltage(V)'],df6['PVP Electrode Current (A)'])

# %%
pvp_7 = df7[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df7['Voltage(V)'],df7['PVP Electrode Current (A)'])

# %%
pvp_8 = df8[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df8['Voltage(V)'],df8['PVP Electrode Current (A)'])

# %%
pvp_9 = df9[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df9['Voltage(V)'],df9['PVP Electrode Current (A)'])

# %%
pvp_10 = df10[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df10['Voltage(V)'],df10['PVP Electrode Current (A)'])

# %%
pvp_11 = df11[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df11['Voltage(V)'],df11['PVP Electrode Current (A)'])

# %%
pvp_12 = df12[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df12['Voltage(V)'],df12['PVP Electrode Current (A)'])

# %%
pvp_13 = df13[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df13['Voltage(V)'],df13['PVP Electrode Current (A)'])

# %%
pvp_14 = df14[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df14['Voltage(V)'],df14['PVP Electrode Current (A)'])

# %%
pvp_15 = df15[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df15['Voltage(V)'],df15['PVP Electrode Current (A)'])

# %%
pvp_16 = df16[['Voltage(V)','PVP Electrode Current (A)']]
plt.plot(df16['Voltage(V)'],df16['PVP Electrode Current (A)'])

# %%
Sg17 = scipy.signal.stft(pvp_1['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_1['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_1['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt17.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg18 = scipy.signal.stft(pvp_2['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_2['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_2['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt18.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg19 = scipy.signal.stft(pvp_3['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_3['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_3['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt19.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg20 = scipy.signal.stft(pvp_4['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_4['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_4['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt20.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg21 = scipy.signal.stft(pvp_5['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_5['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_5['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt21.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg22 = scipy.signal.stft(pvp_6['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_6['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_6['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt22.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg23 = scipy.signal.stft(pvp_7['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_7['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_7['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt23.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg24 = scipy.signal.stft(pvp_8['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_8['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_8['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt24.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg25 = scipy.signal.stft(pvp_9['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_9['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_9['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt25.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg26 = scipy.signal.stft(pvp_10['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_10['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_10['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt26.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg27 = scipy.signal.stft(pvp_11['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_11['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_11['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt27.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg28 = scipy.signal.stft(pvp_12['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_12['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_12['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt28.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg29 = scipy.signal.stft(pvp_13['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_13['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_13['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt29.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg30 = scipy.signal.stft(pvp_14['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_14['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_14['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt30.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg31 = scipy.signal.stft(pvp_15['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_15['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_15['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt31.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg32 = scipy.signal.stft(pvp_16['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(pvp_16['PVP Electrode Current (A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(pvp_16['PVP Electrode Current (A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt32.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
chitosan_1 = df[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df['Voltage(V)'],df['Chitosan Electrode Current(A)'])

# %%
chitosan_2 = df2[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df2['Voltage(V)'],df2['Chitosan Electrode Current(A)'])

# %%
chitosan_3 = df3[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df3['Voltage(V)'],df3['Chitosan Electrode Current(A)'])

# %%
chitosan_4 = df4[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df4['Voltage(V)'],df4['Chitosan Electrode Current(A)'])

# %%
chitosan_5 = df5[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df5['Voltage(V)'],df5['Chitosan Electrode Current(A)'])

# %%
chitosan_6 = df6[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df6['Voltage(V)'],df6['Chitosan Electrode Current(A)'])

# %%
chitosan_7 = df7[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df7['Voltage(V)'],df7['Chitosan Electrode Current(A)'])

# %%
chitosan_8 = df8[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df8['Voltage(V)'],df8['Chitosan Electrode Current(A)'])

# %%
chitosan_9 = df9[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df9['Voltage(V)'],df9['Chitosan Electrode Current(A)'])

# %%
chitosan_10 = df10[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df10['Voltage(V)'],df10['Chitosan Electrode Current(A)'])

# %%
chitosan_11 = df11[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df11['Voltage(V)'],df11['Chitosan Electrode Current(A)'])

# %%
chitosan_12 = df12[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df12['Voltage(V)'],df12['Chitosan Electrode Current(A)'])

# %%
chitosan_13 = df13[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df13['Voltage(V)'],df13['Chitosan Electrode Current(A)'])

# %%
chitosan_14 = df14[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df14['Voltage(V)'],df14['Chitosan Electrode Current(A)'])

# %%
chitosan_15 = df15[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df15['Voltage(V)'],df15['Chitosan Electrode Current(A)'])

# %%
chitosan_16 = df16[['Voltage(V)','Chitosan Electrode Current(A)']]
plt.plot(df16['Voltage(V)'],df16['Chitosan Electrode Current(A)'])

# %%
Sg33 = scipy.signal.stft(chitosan_1['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_1['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_1['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt33.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg34 = scipy.signal.stft(chitosan_2['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_2['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_2['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt34.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg35 = scipy.signal.stft(chitosan_3['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_3['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_3['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt35.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg36 = scipy.signal.stft(chitosan_4['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_4['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_4['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt36.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg37 = scipy.signal.stft(chitosan_5['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_5['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_5['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt37.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg38 = scipy.signal.stft(chitosan_6['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_6['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_6['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt38.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg39 = scipy.signal.stft(chitosan_7['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_7['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_7['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt39.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg40 = scipy.signal.stft(chitosan_8['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_8['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_8['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt40.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg41 = scipy.signal.stft(chitosan_9['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_9['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_9['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt41.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg42 = scipy.signal.stft(chitosan_10['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_10['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_10['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt42.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg43 = scipy.signal.stft(chitosan_11['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_11['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_11['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt43.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg44 = scipy.signal.stft(chitosan_12['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_12['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_12['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt44.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg45 = scipy.signal.stft(chitosan_13['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_13['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_13['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt45.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg46 = scipy.signal.stft(chitosan_14['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_14['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_14['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt46.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg47 = scipy.signal.stft(chitosan_15['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_15['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_15['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt47.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg48 = scipy.signal.stft(chitosan_16['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosan_16['Chitosan Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosan_16['Chitosan Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt48.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
chitosango_1 = df[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df['Voltage(V)'],df['Chitosan GO Electrode Current(A)'])

# %%
chitosango_2 = df2[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df2['Voltage(V)'],df2['Chitosan GO Electrode Current(A)'])

# %%
chitosango_3 = df3[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df3['Voltage(V)'],df3['Chitosan GO Electrode Current(A)'])

# %%
chitosango_4 = df4[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df4['Voltage(V)'],df4['Chitosan GO Electrode Current(A)'])

# %%
chitosango_5 = df5[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df5['Voltage(V)'],df5['Chitosan GO Electrode Current(A)'])

# %%
chitosango_6 = df6[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df6['Voltage(V)'],df6['Chitosan GO Electrode Current(A)'])

# %%
chitosango_7 = df7[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df7['Voltage(V)'],df7['Chitosan GO Electrode Current(A)'])

# %%
chitosango_8 = df8[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df8['Voltage(V)'],df8['Chitosan GO Electrode Current(A)'])

# %%
chitosango_9 = df9[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df9['Voltage(V)'],df9['Chitosan GO Electrode Current(A)'])

# %%
chitosango_10 = df10[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df10['Voltage(V)'],df10['Chitosan GO Electrode Current(A)'])

# %%
chitosango_11 = df11[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df11['Voltage(V)'],df11['Chitosan GO Electrode Current(A)'])

# %%
chitosango_12 = df12[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df12['Voltage(V)'],df12['Chitosan GO Electrode Current(A)'])

# %%
chitosango_13 = df13[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df13['Voltage(V)'],df13['Chitosan GO Electrode Current(A)'])

# %%
chitosango_14 = df14[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df14['Voltage(V)'],df14['Chitosan GO Electrode Current(A)'])

# %%
chitosango_15 = df15[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df15['Voltage(V)'],df15['Chitosan GO Electrode Current(A)'])

# %%
chitosango_16 = df16[['Voltage(V)','Chitosan GO Electrode Current(A)']]
plt.plot(df16['Voltage(V)'],df16['Chitosan GO Electrode Current(A)'])

# %%
Sg49 = scipy.signal.stft(chitosango_1['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_1['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_1['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt49.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg50 = scipy.signal.stft(chitosango_2['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_2['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_2['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt50.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg51 = scipy.signal.stft(chitosango_3['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_3['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_3['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt51.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg52 = scipy.signal.stft(chitosango_4['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_4['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_4['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt52.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg53 = scipy.signal.stft(chitosango_5['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_5['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_5['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt53.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg54 = scipy.signal.stft(chitosango_6['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_6['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_6['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt54.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg55 = scipy.signal.stft(chitosango_7['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_7['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_7['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt55.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg56 = scipy.signal.stft(chitosango_8['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_8['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_8['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt56.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg57 = scipy.signal.stft(chitosango_9['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_9['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_9['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt57.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg58 = scipy.signal.stft(chitosango_10['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_10['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_10['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt58.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg59 = scipy.signal.stft(chitosango_11['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_11['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_11['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt59.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg60 = scipy.signal.stft(chitosango_12['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_12['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_12['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt60.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg61 = scipy.signal.stft(chitosango_13['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_13['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_13['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt61.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg62 = scipy.signal.stft(chitosango_14['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_14['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_14['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt62.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg63 = scipy.signal.stft(chitosango_15['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_15['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_15['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt63.png', dpi=300, quality=80, optimize=True, progressive=True)

# %%
Sg64 = scipy.signal.stft(chitosango_16['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None, detrend=False, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
f, Pxx_den = scipy.signal.welch(chitosango_16['Chitosan GO Electrode Current(A)'], fs=1.0, window='hann', nperseg=None, noverlap=None, nfft=None, detrend='constant', return_onesided=True, scaling='density', axis=- 1, average='mean')
Pxx_den_db = 10*np.log10(Pxx_den)
mn = np.min(Pxx_den_db)
mx = np.max(Pxx_den_db)
f, t, Sxx = signal.spectrogram(np.array(chitosango_16['Chitosan GO Electrode Current(A)'][0:2000]), fs=256, nperseg=256, noverlap=int(256*0.95), scaling='density', return_onesided=True)
normalize_color= matplotlib.colors.Normalize(vmin=mn, vmax=mx)
Sxx = 10*np.log10(Sxx)
plt.pcolormesh(t, f, Sxx, cmap='jet', norm=normalize_color)
plt.colorbar(label='Power (dB)')
plt.savefig('plt64.png', dpi=300, quality=80, optimize=True, progressive=True)
