# %% [markdown]
# <a href="https://colab.research.google.com/github/Onkar627/Sensor_Electrodes/blob/main/images_pvp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('plt17.png')
plt.axis('off')
imS = cv2.resize(img, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp1.png")

# %%
img2 = cv2.imread('plt18.png')
plt.axis('off')
imS = cv2.resize(img2, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp2.png")

# %%
img3 = cv2.imread('plt19.png')
plt.axis('off')
imS = cv2.resize(img4, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp3.png")

# %%
img4= cv2.imread('plt20.png')
plt.axis('off')
imS = cv2.resize(img4, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp4.png")

# %%
img5 = cv2.imread('plt21.png')
plt.axis('off')
imS = cv2.resize(img5, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp5.png")

# %%
img6 = cv2.imread('plt22.png')
plt.axis('off')
imS = cv2.resize(img6, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp6.png")

# %%
img7 = cv2.imread('plt23.png')
plt.axis('off')
imS = cv2.resize(img7, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp7.png")

# %%
img8 = cv2.imread('plt24.png')
plt.axis('off')
imS = cv2.resize(img8, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp8.png")

# %%
img9 = cv2.imread('plt25.png')
plt.axis('off')
imS = cv2.resize(img9, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp9.png")

# %%
img10 = cv2.imread('plt26.png')
plt.axis('off')
imS = cv2.resize(img10, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp10.png")

# %%
img11 = cv2.imread('plt27.png')
plt.axis('off')
imS = cv2.resize(img11, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp11.png")

# %%
img12 = cv2.imread('plt28.png')
plt.axis('off')
imS = cv2.resize(img12, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp12.png")

# %%
img13 = cv2.imread('plt29.png')
plt.axis('off')
imS = cv2.resize(img13, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp13.png")

# %%
img14 = cv2.imread('plt30.png')
plt.axis('off')
imS = cv2.resize(img14, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp14.png")

# %%
img15 = cv2.imread('plt31.png')
plt.axis('off')
imS = cv2.resize(img15, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp15.png")

# %%
img16 = cv2.imread('plt32.png')
plt.axis('off')
imS = cv2.resize(img16, (600, 600)) 
cut_img = imS[380:600,0:600]
plt.imshow(cut_img)
imS.shape
plt.savefig("crp16.png")
